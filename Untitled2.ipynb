# %%
import pandas as pd
df=pd.read_csv("C:\python code\pandas\movies.csv" )
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\shish\AppData\Local\Temp\ipykernel_3896\4276520961.py:2: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_csv("C:\python code\pandas\movies.csv" )
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# ...

# %%
df=pd.read_csv(r"C:\python code\pandas\movies.csv", header=1, nrows=5 )
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.read_csv(r"C:\python code\pandas\movies.csv", header=1, ncolumns=5 )
#       2 df
#
# TypeError: read_csv() got an unexpected keyword argument 'ncolumns'
